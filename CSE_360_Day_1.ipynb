# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishan1082/Deep-Learning/blob/main/CSE_360_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ANN Model

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/diabetes - diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
#spliting the data

X=df.iloc[:, :8]
y=df.iloc[:,-1]

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
#Define the keras model

model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer ='adam', metrics = ['accuracy'])

# %%
#fit the model on the dataset
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 1.2072 - accuracy: 0.5339
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7176 - accuracy: 0.6289
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6871 - accuracy: 0.6458
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6845 - accuracy: 0.6484
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6821 - accuracy: 0.6497
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6799 - accuracy: 0.6497
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6777 - accuracy: 0.6497
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6758 - accuracy: 0.6497
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6737 - accuracy: 0.6497
# Epoch 10/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 12)                108
#
#  dense_1 (Dense)             (None, 8)                 104
#
#  dense_2 (Dense)             (None, 6)                 54
#
#  dense_3 (Dense)             (None, 4)                 28
#
#  dense_4 (Dense)             (None, 2)                 10
#
#  dense_5 (Dense)             (None, 1)                 3
#
# ...
# Total params: 307
# Trainable params: 307
# Non-trainable params: 0
# _________________________________________________________________
